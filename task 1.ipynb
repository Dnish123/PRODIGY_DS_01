# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#   Country Name Country Code  \
# 0        India          IND
# 1        India          IND
# 2        India          IND
# 3          NaN          NaN
# 4          NaN          NaN
#
#                                          Series Name        Series Code  \
# 0            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 1  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 3                                                NaN                NaN
# 4                                                NaN                NaN
#
#    2017 [YR2017]  2018 [YR2018]  2019 [YR2019]  2020 [YR2020]  2021 [YR2021]  \
# 0           91.8           95.7           95.9           96.5           99.6
# 1           88.3           93.9           93.8           95.2           99.3
# 2           98.7           99.1           99.8           99.0          100.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   5 non-null      object
#  1   Country Code   3 non-null      object
#  2   Series Name    3 non-null      object
#  3   Series Code    3 non-null      object
#  4   2017 [YR2017]  3 non-null      float64
#  5   2018 [YR2018]  3 non-null      float64
#  6   2019 [YR2019]  3 non-null      float64
#  7   2020 [YR2020]  3 non-null      float64
#  8   2021 [YR2021]  3 non-null      float64
#  9   2022 [YR2022]  3 non-null      float64
#  10  2023 [YR2023]  3 non-null      object
# dtypes: float64(6), object(5)
# memory usage: 832.0+ bytes

# %%
#plot Bar graph
data = pd.DataFrame(df)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,3,1])
x = list(data.iloc[:0])
y = list(data.iloc[:1])
ax.bar(x,y,color='b')
plt.show()
